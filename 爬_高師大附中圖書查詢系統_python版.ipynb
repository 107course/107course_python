# %%
import requests
import re
import json
from bs4 import BeautifulSoup

keyword = input()
formdata={
    'ToolkitScriptManager1_HiddenField':'',
    '__EVENTTARGET':'ctl00$ContentPlaceHolder1$UcRankLoan$lbtn_Rank_title',
'__EVENTARGUMENT':'',
    '__VIEWSTATE':'...',
'__VIEWSTATEGENERATOR':'4DE51EF8',
'__VIEWSTATEENCRYPTED':'',
    '__EVENTVALIDATION':'...',
'ctl00$ContentPlaceHolder1$hid_Right':'1',
'ctl00$ContentPlaceHolder1$UcQuickSearch$hid_SearchTab_Index':'0',
'ctl00$ContentPlaceHolder1$UcQuickSearch$txt_SearchTab':keyword,
'ctl00$ContentPlaceHolder1$UcQuickSearch$btn_SearchTab':'搜尋'
}
res = requests.post("http://163.32.92.129/OPAC850/", data=formdata)
soup = BeautifulSoup(res.text, 'lxml')
list = []
for item in soup.find_all("tr", id=re.compile("(.*)ProductsRow$")):
    #print("item=",item) # 取消註解觀察抓到的資料。    
    trtrtdi = 0
    dic = {}
    for trtr in item.find_all("tr"):
        for trtrtd in trtr.find_all("td"):
            #trtrtd = ' '.join(trtrtd.text.split()).split()
            trtrtd = trtrtd.text.strip()
            trtrtd = ' '.join(trtrtd.split()) # 由於資料當中有許多不必要的空白，因此切斷後補空白再接起來。
            print("trtrtd",trtrtdi,"=", trtrtd)
            if trtrtdi == 1:
                dic['bookname'] = trtrtd
            if trtrtdi == 3:
                dic['author'] = trtrtd
            if trtrtdi == 4:
                dic['publisher'] = trtrtd
            if trtrtdi == 5:
                dic['year'] = trtrtd
            trtrtdi = trtrtdi + 1
    list.append(dic)
print(json.dumps(list,ensure_ascii=False))
# Out:
# art
# trtrtd 0 =
# trtrtd 1 = 1. 換一種眼光看美
# trtrtd 2 = 資料別: 圖書
# trtrtd 3 = 作者: 亞瑟．丹托(Arthur C. Danto)作;鄧伯宸譯
# trtrtd 4 = 出版者: 立緒文化
# trtrtd 5 = 出版年: 民97[2008]
# trtrtd 0 =
# trtrtd 1 = 2. 非常有藝思=Have fun with art
# trtrtd 2 = 資料別: 非書媒體
# trtrtd 3 = 作者: 財團法人公共電視文化事業企畫製作
# trtrtd 4 = 出版者: 公共電視
# trtrtd 5 = 出版年: 民96[2007]
# trtrtd 0 =
# trtrtd 1 = 3. 新聞文化:報紙.廣播.電視如何製造真相?
# trtrtd 2 = 資料別: 圖書
# trtrtd 3 = 作者: Stuart Allan著;陳雅玫譯
# trtrtd 4 = 出版者: 書林
# trtrtd 5 = 出版年: 民95
# trtrtd 0 =
# trtrtd 1 = 4. 場域游走:互動公共藝術=Interactive public art
# trtrtd 2 = 資料別: 圖書
# trtrtd 3 = 作者: 顏名宏著
# trtrtd 4 = 出版者: 文建會
# trtrtd 5 = 出版年: 民94[2005]
# trtrtd 0 =
# trtrtd 1 = 5. 創意地帶:園區公共藝術=Public art in park
# trtrtd 2 = 資料別: 圖書
# trtrtd 3 = 作者: 郭瑞坤,郭彰仁著
# trtrtd 4 = 出版者: 文建會
# trtrtd 5 = 出版年: 民94[2005]
# trtrtd 0 =
# trtrtd 1 = 6. 自然製造:生態公共藝術=Ecological public art
# trtrtd 2 = 資料別: 圖書
# trtrtd 3 = 作者: 郭瓊瑩著
# trtrtd 4 = 出版者: 文建會
# trtrtd 5 = 出版年: 民94[2005]
# trtrtd 0 =
# trtrtd 1 = 7. 彩墨小品輕鬆畫
# trtrtd 2 = 資料別: 圖書
# trtrtd 3 = 作者: 小林東雲著;蘇蔚琳譯
# trtrtd 4 = 出版者: 積木文化出版:家庭傳媒城邦分公司發行
# trtrtd 5 = 出版年: 民94[2005]
# trtrtd 0 =
# trtrtd 1 = 8. 圖解水墨畫
# trtrtd 2 = 資料別: 圖書
# trtrtd 3 = 作者: 小林東雲著;沙子芳譯
# trtrtd 4 = 出版者: 積木文化出版:家庭傳媒城邦分公司發行
# trtrtd 5 = 出版年: 民94[2005]
# trtrtd 0 =
# trtrtd 1 = 9. 絲路上的寶藏:敦煌石窟藝術=Treasure of the Silk Road:the art of Dunhuang
# trtrtd 2 = 資料別: 圖書
# trtrtd 3 = 作者: 周旻樺文;黃淑女圖.
# trtrtd 4 = 出版者: 史博館
# trtrtd 5 = 出版年: 民94.
# trtrtd 0 =
# trtrtd 1 = 10. 樂音飛揚=Birth of an artist music
# trtrtd 2 = 資料別: 圖書
# trtrtd 3 = 作者: 曾溥勻作;恩佐插畫.
# trtrtd 4 = 出版者: 國立臺灣藝術教育館
# trtrtd 5 = 出版年: 民94.
# trtrtd 0 =
# trtrtd 1 = 11. 舞動人生=Birth of an artist dance
# trtrtd 2 = 資料別: 圖書
# trtrtd 3 = 作者: 黃尹瑩作;潘昀珈插畫.
# trtrtd 4 = 出版者: 國立臺灣藝術教育館
# trtrtd 5 = 出版年: 民94.
# trtrtd 0 =
# trtrtd 1 = 12. 打造美樂地:社區公共藝術=Public art in community
# trtrtd 2 = 資料別: 圖書
# trtrtd 3 = 作者: 曾旭正著
# trtrtd 4 = 出版者: 文建會
# trtrtd 5 = 出版年: 民94
# trtrtd 0 =
# trtrtd 1 = 13. 藝術學堂:校園公共藝術=Public art in school
# trtrtd 2 = 資料別: 圖書
# trtrtd 3 = 作者: 王玉齡著
# trtrtd 4 = 出版者: 文建會
# trtrtd 5 = 出版年: 民94
# trtrtd 0 =
# trtrtd 1 = 14. 街頭美學:設施公共藝術=Facility public art
# trtrtd 2 = 資料別: 圖書
# trtrtd 3 = 作者: 林熹俊著
# trtrtd 4 = 出版者: 文建會
# trtrtd 5 = 出版年: 民94
# trtrtd 0 =
# trtrtd 1 = 15. 科學漫畫.Part II
# trtrtd 2 = 資料別: 圖書
# trtrtd 3 = 作者: 黃天雄作;陳玉嵐繪圖.
# trtrtd 4 = 出版者: 科學教育館
# trtrtd 5 = 出版年: 民93.
# [{"year": "出版年: 民97[2008]", "publisher": "出版者: 立緒文化", "bookname": "1. 換一種眼光看美", "author": "作者: 亞瑟．丹托(Arthur C. Danto)作;鄧伯宸譯"}, {"year": "出版年: 民96[2007]", "publisher": "出版者: 公共電視", "bookname": "2. 非常有藝思=Have fun with art", "author": "作者: 財團法人公共電視文化事業企畫製作"}, {"year": "出版年: 民95", "publisher": "出版者: 書林", "bookname": "3. 新聞文化:報紙.廣播.電視如何製造真相?", "author": "作者: Stuart Allan著;陳雅玫譯"}, {"year": "出版年: 民94[2005]", "publisher": "出版者: 文建會", "bookname": "4. 場域游走:互動公共藝術=Interactive public art", "author": "作者: 顏名宏著"}, {"year": "出版年: 民94[2005]", "publisher": "出版者: 文建會", "bookname": "5. 創意地帶:園區公共藝術=Public art in park", "author": "作者: 郭瑞坤,郭彰仁著"}, {"year": "出版年: 民94[2005]", "publisher": "出版者: 文建會", "bookname": "6. 自然製造:生態公共藝術=Ecological public art", "author": "作者: 郭瓊瑩著"}, {"year": "出版年: 民94[2005]", "publisher": "出版者: 積木文化出版:家庭傳媒城邦分公司發行", "bookname": "7. 彩墨小品輕鬆畫", "author": "作者: 小林東雲著;蘇蔚琳譯"}, {"year": "出版年: 民94[2005]", "publisher": "出版者: 積木文化出版:家庭傳媒城邦分公司發行", "bookname": "8. 圖解水墨畫", "author": "作者: 小林東雲著;沙子芳譯"}, {"year": "出版年: 民94.", "publisher": "出版者: 史博館", "bookname": "9. 絲路上的寶藏:敦煌石窟藝術=Treasure of the Silk Road:the art of Dunhuang", "author": "作者: 周旻樺文;黃淑女圖."}, {"year": "出版年: 民94.", "publisher": "出版者: 國立臺灣藝術教育館", "bookname": "10. 樂音飛揚=Birth of an artist music", "author": "作者: 曾溥勻作;恩佐插畫."}, {"year": "出版年: 民94.", "publisher": "出版者: 國立臺灣藝術教育館", "bookname": "11. 舞動人生=Birth of an artist dance", "author": "作者: 黃尹瑩作;潘昀珈插畫."}, {"year": "出版年: 民94", "publisher": "出版者: 文建會", "bookname": "12. 打造美樂地:社區公共藝術=Public art in community", "author": "作者: 曾旭正著"}, {"year": "出版年: 民94", "publisher": "出版者: 文建會", "bookname": "13. 藝術學堂:校園公共藝術=Public art in school", "author": "作者: 王玉齡著"}, {"year": "出版年: 民94", "publisher": "出版者: 文建會", "bookname": "14. 街頭美學:設施公共藝術=Facility public art", "author": "作者: 林熹俊著"}, {"year": "出版年: 民93.", "publisher": "出版者: 科學教育館", "bookname": "15. 科學漫畫.Part II", "author": "作者: 黃天雄作;陳玉嵐繪圖."}]

# %%
# 聖功圖書查詢網頁。

import requests
import re
import json
from bs4 import BeautifulSoup

keyword = input()

formdata={
    '__LASTFOCUS':'',
'__EVENTTARGET':'',
'__EVENTARGUMENT':'',
'__VIEWSTATE':'...',
'ctl00$Hidden1':'請輸入S+學號、T+教職員編號',
'ctl00$Hidden2':'請輸入圖書館核發密碼',
'ctl00$Hidden3':'請輸入S+學號、T+教職員編號',
'ctl00$Hidden4':'1',
'ctl00$Hidden5':'',
'ctl00$hiddMenu':'1',
'ctl00$hiddMenu2':'1',
'ctl00$hiddMenu3':'7',
'ctl00$TextBox1':'',
'ctl00$TextBox2':'',
'ctl00$ContentPlaceHolder1$ListBox1':'Info000072',
'ctl00$ContentPlaceHolder1$ListBox2':'Info000080',
'ctl00$ContentPlaceHolder1$TextBox1':keyword,
'ctl00$ContentPlaceHolder1$ImageButton1.x':'11',
'ctl00$ContentPlaceHolder1$ImageButton1.y':'13',
'ctl00$ContentPlaceHolder1$radtype':'任意',
'it1':'日文平假名',
'ctl00$ContentPlaceHolder1$Hidden1':'',
'__EVENTVALIDATION':'...'
}

res = requests.post("http://203.72.42.6/webopac/Jycx.aspx?dc=1&fc=1&n=7", data=formdata)
soup = BeautifulSoup(res.text, 'lxml')
list = []
for item in soup.find_all("tr", attrs={'style':'height:24px;'}):
    tdindex = 0
    dic = {}
    for tdd in item.find_all("td"):
        # print(tdindex, tdd.text.strip()) # 取消註解觀察是第幾個 td
        if tdindex == 2:
            dic['bookname'] = tdd.text.strip()
        if tdindex == 3:
            dic['author'] = tdd.text.strip()
        tdindex = tdindex +1
    list.append(dic)
print(json.dumps(list,ensure_ascii=False))
# Out:
# 三國
# [{"bookname": "＜<三國演義>>之美學解讀", "author": "陳瑞秀著/文津"}, {"bookname": "34位三國志軍師小事典", "author": "渡邊義浩/商周出版"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS  三國演義 (第七集)", "author": "羅貫忠 著/亞太圖書"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS (三國演義 3  )", "author": "羅貫中 著/亞太圖書公司"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS (三國演義 4)", "author": "羅貫中 著/亞太圖書公司"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS (三國演義 5)", "author": "羅貫中著/亞太圖書公司"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS (三國演義 5)", "author": "羅貫中 著/亞太圖書"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS (三國演義 7)", "author": "羅貫中 著/亞太圖書公司"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS (三國演義 8)", "author": "羅貫中 著/亞太圖書"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS (三國演義 8)", "author": "羅貫中 著/亞太圖書公司"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS (三國演義) 第二冊", "author": "羅貫忠 著/亞太圖書"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS (三國誌)", "author": "蔡志忠 編/亞太圖書"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS (三國誌)", "author": "蔡志忠 編/亞太圖書公司"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS 三國演義 (第九冊)", "author": "羅貫中著/亞太圖書"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS 三國演義 (第十冊)", "author": "羅貫中著/亞太圖書"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS 三國演義(第一冊)", "author": "羅貫中原著/亞太圖書"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS 三國演義第十冊", "author": "羅貫中原著/亞太"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS 三國誌", "author": "蔡志忠編著/亞太圖書"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS三國演義(第一冊)", "author": "羅貫中原著/亞太"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS三國演義(第九冊)", "author": "羅貫中原著/亞太圖書"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS三國演義(第三冊)", "author": "羅貫中原著/亞太圖書"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS三國演義(第六冊)", "author": "羅貫中原著/亞太"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS三國演義(第六冊)", "author": "羅貫中原著/亞太"}, {"bookname": "ROMANCE OF THE THREE KINGDOMS三國演義(第四冊)", "author": "羅貫中原著/亞太"}, {"bookname": "ROMANCE OF THREE KINGDOMS (三國演義 2)", "author": "羅貫中 著/亞太圖書"}, {"bookname": "三國=Three kingdoms;高希希導演", "author": "高希希/北京東方恒和影視文化發行"}, {"bookname": "三國人物與故事", "author": "倪世槐著/三民書局"}, {"bookname": "三國古戰場--古典中國之旅2", "author": "顏崑陽/故鄉出版社"}, {"bookname": "三國志", "author": "黃中憲編/錦繡"}, {"bookname": "三國志 : 必勝的要訣", "author": "王淑妙著/西北"}, {"bookname": "三國志人物事典", "author": "小出文彥/霹靂新潮社出版"}, {"bookname": "三國志之旅", "author": "愛書人雜誌編/號角"}, {"bookname": "三國志的世界", "author": "駒田信二/萬象"}, {"bookname": "三國傳說趣譚", "author": "王登雲主編/旺文"}, {"bookname": "三國傳說趣譚", "author": "王登雲主編/旺文"}, {"bookname": "三國新義", "author": "法務部著/法務部"}, {"bookname": "三國鼎立：一時多少英雄豪傑, 西元184~280年", "author": "李飛/莎士比亞文化出版"}, {"bookname": "三國演義", "author": "文心工作室/商周出版"}, {"bookname": "三國演義", "author": "羅貫中編著/冠一"}, {"bookname": "三國演義", "author": "羅貫中/聯經"}, {"bookname": "三國演義", "author": "(明)羅貫中/博元出版社"}, {"bookname": "三國演義(一)", "author": "王玉文字編輯/王玉文字編輯"}, {"bookname": "三國演義(二)", "author": "王玉文字編輯/王玉文字編輯"}, {"bookname": "三國演義(三)", "author": "王玉文字編輯/王玉文字編輯"}, {"bookname": "三國演義(五)", "author": "王玉文字編輯/王玉文字編輯"}, {"bookname": "三國演義(六)", "author": "王玉文字編輯/王玉文字編輯"}, {"bookname": "三國演義(四)", "author": "王玉文字編輯/王玉文字編輯"}, {"bookname": "三國演義. 1, 亂世狼煙", "author": "羅貫中/閣林國際圖書"}, {"bookname": "三國演義. 10, 大戰長&#22338;坡", "author": "羅貫中/閣林國際圖書"}, {"bookname": "三國演義. 11, 火燒赤壁", "author": "羅貫中/閣林國際"}]
